# %%
import tensorflow as tf
import tensorflow.contrib.slim as slim
import tensorflow.contrib.slim.nets

import numpy as np
import os

from PIL import Image

# %%
VGG_MEAN = [123.68, 116.78, 103.94]

# %%
x_train_path = './processed_data/x_train.npy'
y_train_path = './processed_data/y_train.npy'
x_val_path = './processed_data/x_val.npy'
y_val_path = './processed_data/y_val.npy'
model_path = 'vgg_16.ckpt'
batch_size = 32
num_workers = 4
num_epochs1 = 1500
const_learning_rate1 = 1e-4
dropout_keep_prob = 0.5
weight_decay = 5e-4

# %%
# load training and validation data
x_train = np.load(x_train_path)
y_train = np.load(y_train_path)
x_val = np.load(x_val_path)
y_val = np.load(y_val_path)

total_images = x_train.shape[0]

# %%
def check_accuracy(sess, error, is_training,
                  dataset_init_op):
    """
    Check the accuracy of the model on either train 
    or val (depending on dataset_init_op).
    """
    # Initialize the correct dataset
    sess.run(dataset_init_op)
    err = []
    while True:
        try:
            mse, op = sess.run(error, {is_training: False})
            err.append(float(mse))
        except tf.errors.OutOfRangeError:
            break
    
    return sum(err)/float(len(err))

def save_checkpoint(saver, init_err, val_err, sess, epoch, name):
    if val_err < init_err:
        init_err = val_err
        save_path = './checks/' + name
        saver.save(sess, 
                    save_path,
                    global_step=epoch,
                    write_meta_graph=True)
    return init_err    

def get_arrays(fold=None):
    if fold == "train":
        return x_train, y_train
    else:
        return x_val, y_val

# %%
def main():
    x_train, y_train = get_arrays(fold="train")
    x_val, y_val = get_arrays(fold="val")
    
    num_classes = 30
    
    graph = tf.Graph()
    with graph.as_default():
        # Standard preprocessing for VGG on ImageNet
        def _parse_function(image, keypoints):
            image = tf.reshape(image, [96, 96, 1])
            
            rgb_image = tf.image.grayscale_to_rgb(image)
            image = tf.cast(rgb_image, tf.float32)
            
            # changing resolution according from 48x48 to 256x256
            resized_image = tf.image.resize_images(image, tf.constant([256, 256]))
            
            return resized_image, keypoints
        
        # Preprocessing for training
        def training_preprocess(image, keypoints):
            # Random Crop
            crop_image = tf.random_crop(image, [224, 224, 3])
            flip_image = tf.image.random_flip_left_right(crop_image)
            
            means = tf.reshape(tf.constant(VGG_MEAN), [1, 1, 3])
            centered_image = flip_image - means
            
            return centered_image, keypoints
        
        # Preprocessing for validation
        def val_preprocess(image, keypoints):
            # Central Crop
            crop_image = tf.image.resize_image_with_crop_or_pad(image, 224, 224)
            
            means = tf.reshape(tf.constant(VGG_MEAN), [1, 1, 3])
            centered_image = crop_image - means
            
            return centered_image, keypoints
        
        # DATASET CREATION using tf.contrib.data.Dataset
        
        # Training dataset
        x_train = tf.constant(x_train)
        y_train = tf.constant(y_train)
        
        train_dataset = tf.contrib.data.Dataset.from_tensor_slices((x_train, y_train))
        train_dataset = train_dataset.map(_parse_function,
                        num_threads=num_workers,
                        output_buffer_size=batch_size)
        train_dataset = train_dataset.map(training_preprocess,
                        num_threads=num_workers, 
                        output_buffer_size=batch_size)
        train_dataset = train_dataset.shuffle(buffer_size=10000) # don't forget to shuffle
        batched_train_dataset = train_dataset.batch(batch_size)
        
        # Validation dataset
        x_val = tf.constant(x_val)
        y_val = tf.constant(y_val)
        
        val_dataset = tf.contrib.data.Dataset.from_tensor_slices((x_val, y_val))
        val_dataset = val_dataset.map(_parse_function,
                        num_threads=num_workers, 
                        output_buffer_size=batch_size)
        val_dataset = val_dataset.map(val_preprocess, 
                        num_threads=num_workers, 
                        output_buffer_size=batch_size)
        batched_val_dataset = val_dataset.batch(batch_size)
        
        # Now define the Iterator that can operate on
        # any of the datasets
        # Once this is done, we don't need to feed any value for images and labels
        # as they are automatically pulled out from the iterator queues.
        
        iterator = tf.contrib.data.Iterator.from_structure(batched_train_dataset.output_types,
                                                          batched_train_dataset.output_shapes)
        
        images, keypoints = iterator.get_next()
        
        train_init_op = iterator.make_initializer(batched_train_dataset)
        val_init_op = iterator.make_initializer(batched_val_dataset)
        
        # Create a placeholder to indicate if we are in training or validation phase
        is_training = tf.placeholder(tf.bool)
        
        # Get the pretrained VGG16 ready
        vgg = tf.contrib.slim.nets.vgg
        with slim.arg_scope(vgg.vgg_arg_scope(weight_decay=weight_decay)):
            predictions, _ = vgg.vgg_16(images, num_classes=num_classes, 
                                   is_training=is_training, 
                                  dropout_keep_prob=dropout_keep_prob)
            
        # specify model checkpoint path
        assert(os.path.isfile(model_path))
        
        # Restore only convolutional layers and not fully connected ones
        variables_to_restore = tf.contrib.framework.get_variables_to_restore(exclude=['vgg_16/fc6',
                                                                                    'vgg_16/fc7',
                                                                                      'vgg_16/fc8'])
        
        init_fn = tf.contrib.framework.assign_from_checkpoint_fn(model_path, variables_to_restore)
        
        # Initialization operation for all three fully connected layers
        fc6_variables = tf.contrib.framework.get_variables('vgg_16/fc6')
        fc6_init = tf.variables_initializer(fc6_variables)
        fc7_variables = tf.contrib.framework.get_variables('vgg_16/fc7')
        fc7_init = tf.variables_initializer(fc7_variables)
        fc8_variables = tf.contrib.framework.get_variables('vgg_16/fc8')
        fc8_init = tf.variables_initializer(fc8_variables)
        
        # Define loss function 
        tf.losses.mean_squared_error(labels=keypoints,
                                    predictions=predictions)
        loss = tf.losses.get_total_loss()
        
        # For tensorboard
        tf.summary.scalar('loss', loss)
        
        # We will train only for last three layers
        var_list = []
        var_list.append(fc6_variables)
        var_list.append(fc7_variables)
        var_list.append(fc8_variables)
        
        # training op to train complete network
        # with step decay for learning rate
        global_step = tf.Variable(0, trainable=False)
        boundaries = [500, 1000, 1500]
        values = [0.0001, 0.00005, 0.00001, 0.000005]
        learning_rate = tf.train.piecewise_constant(global_step,boundaries,values)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate)
        train_op = optimizer.minimize(loss, var_list=var_list) 
    
        # Evaluation Metrics
        error = tf.metrics.mean_squared_error(labels=keypoints,
                                             predictions=predictions)
        
        # Save built checkpoint
        saver = tf.train.Saver(max_to_keep=3)
        
        # Variables Initializer
        global_init = tf.global_variables_initializer()
        local_init = tf.local_variables_initializer()
        
        summary_op = tf.summary.merge_all()
        
        tf.get_default_graph().finalize()
        
    # Graph has been built, time to throw some computation
    with tf.Session(graph=graph) as sess:
        init_fn(sess) # load the pretrained weights
        sess.run(fc6_init) # initialize the new fc6 layer
        sess.run(fc7_init)
        sess.run(fc8_init)
        
        sess.run(global_init)
        sess.run(local_init)

        init_mse = 1000000.0 # take a big number to compare error
        
        writer = tf.summary.FileWriter("./logs", graph=None)
        
        # Update only last three layers
        for epoch in range(num_epochs1):
            # Track loss
            loss_history = []
            
            # number of batches in one epoch
            batch_count = int(total_images/batch_size)
            
            # Run an epoch over the training data
            print("Starting epoch %d / %d" % (epoch + 1,
                                             num_epochs1))
            # Initialize the iterator with training set
            sess.run(train_init_op)
            
            while True:
                try:
                    _, summary = sess.run([train_op, summary_op],
                                 {is_training: True})
                    loss_history.append(sess.run(loss, 
                                                 {is_training: True}))
                except tf.errors.OutOfRangeError:
                    break
            
            # print average loss per epoch
            epoch_loss = sum(loss_history) / float(len(loss_history))
            print("Loss: %f" %  epoch_loss, end="")
            
            # Check accuracy on the train and val sets every epoch
            #train_mse = check_accuracy(sess, error, is_training, train_init_op)
            val_mse = check_accuracy(sess, error, is_training, val_init_op)
            
            #print("Train MSE: %f" % train_mse)
            print("    Validation MSE: %f" % val_mse)
            
            # Call the function to save the checkpoint
            init_mse = save_checkpoint(saver, init_mse, val_mse, sess,
                           epoch, 'my_model1')
            #print("Checkpoint Saved")
            
            # tensorboard logging
            writer.add_summary(summary, epoch)
            #print("Tensorboard logging complete")

# %%
if __name__ == '__main__':
    main()
# Out:
# WARNING:tensorflow:From <ipython-input-6-0797740394fe>:48: Dataset.from_tensor_slices (from tensorflow.contrib.data.python.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.from_tensor_slices()`.
# WARNING:tensorflow:From <ipython-input-6-0797740394fe>:51: calling Dataset.map (from tensorflow.contrib.data.python.ops.dataset_ops) with output_buffer_size is deprecated and will be removed in a future version.
# Instructions for updating:
# Replace `num_threads=T` with `num_parallel_calls=T`. Replace `output_buffer_size=N` with `ds.prefetch(N)` on the returned dataset.
# WARNING:tensorflow:From <ipython-input-6-0797740394fe>:51: calling Dataset.map (from tensorflow.contrib.data.python.ops.dataset_ops) with num_threads is deprecated and will be removed in a future version.
# Instructions for updating:
# Replace `num_threads=T` with `num_parallel_calls=T`. Replace `output_buffer_size=N` with `ds.prefetch(N)` on the returned dataset.
# INFO:tensorflow:Restoring parameters from vgg_16.ckpt
# Starting epoch 1 / 1500
# Loss: 1240.696931    Validation MSE: 223.989182
# Starting epoch 2 / 1500
# Loss: 248.109277    Validation MSE: 221.568116
# Starting epoch 3 / 1500
# Loss: 222.460108    Validation MSE: 212.833600
# Starting epoch 4 / 1500
# Loss: 201.370837    Validation MSE: 204.258968
# Starting epoch 5 / 1500
# Loss: 186.292660    Validation MSE: 195.961145
# Starting epoch 6 / 1500
# Loss: 162.913122    Validation MSE: 188.632214
# Starting epoch 7 / 1500
# Loss: 142.170686    Validation MSE: 182.828742
# Starting epoch 8 / 1500
# Loss: 135.393735    Validation MSE: 177.373575
# Starting epoch 9 / 1500
# Loss: 131.130509    Validation MSE: 171.649034
# Starting epoch 10 / 1500
# Loss: 121.314902    Validation MSE: 166.521104
# Starting epoch 11 / 1500
# Loss: 120.148602    Validation MSE: 162.380455
# Starting epoch 12 / 1500
# Loss: 118.392618    Validation MSE: 159.038227
# Starting epoch 13 / 1500
# Loss: 115.617191    Validation MSE: 156.201236
# Starting epoch 14 / 1500
# Loss: 112.308022    Validation MSE: 153.295979
# Starting epoch 15 / 1500
# Loss: 112.005687    Validation MSE: 151.404521
# Starting epoch 16 / 1500
# Loss: 107.202155    Validation MSE: 149.852864
# Starting epoch 17 / 1500
# Loss: 106.702651    Validation MSE: 147.455732
# Starting epoch 18 / 1500
# Loss: 107.337739    Validation MSE: 145.055520
# Starting epoch 19 / 1500
# Loss: 103.518460    Validation MSE: 142.709926
# Starting epoch 20 / 1500
# Loss: 105.539641    Validation MSE: 141.004964
# Starting epoch 21 / 1500
# Loss: 100.748763    Validation MSE: 139.326367
# Starting epoch 22 / 1500
# Loss: 99.338958    Validation MSE: 137.214903
# Starting epoch 23 / 1500
# Loss: 94.959526    Validation MSE: 135.269983
# Starting epoch 24 / 1500
# Loss: 94.164076    Validation MSE: 133.561501
# Starting epoch 25 / 1500
# Loss: 94.165113    Validation MSE: 131.916119
# Starting epoch 26 / 1500
# Loss: 91.414532    Validation MSE: 130.172385
# Starting epoch 27 / 1500
# Loss: 90.924478    Validation MSE: 131.046010
# Starting epoch 28 / 1500
# Loss: 89.113309    Validation MSE: 132.060349
# Starting epoch 29 / 1500
# Loss: 84.563612    Validation MSE: 130.490127
# Starting epoch 30 / 1500
# Loss: 87.714118    Validation MSE: 128.741364
# Starting epoch 31 / 1500
# Loss: 83.452379    Validation MSE: 127.174753
# Starting epoch 32 / 1500
# Loss: 81.955326    Validation MSE: 126.301594
# Starting epoch 33 / 1500
# Loss: 81.784816    Validation MSE: 125.283313
# Starting epoch 34 / 1500
# Loss: 75.253184    Validation MSE: 123.677742
# Starting epoch 35 / 1500
# Loss: 77.833034    Validation MSE: 122.113154
# Starting epoch 36 / 1500
# Loss: 78.782816    Validation MSE: 121.002299
# Starting epoch 37 / 1500
# Loss: 74.864661    Validation MSE: 120.401670
# Starting epoch 38 / 1500
# Loss: 72.833939    Validation MSE: 119.373166
# Starting epoch 39 / 1500
# Loss: 73.770269    Validation MSE: 117.899377
# Starting epoch 40 / 1500
# Loss: 70.499069    Validation MSE: 116.461332
# Starting epoch 41 / 1500
# Loss: 67.700637    Validation MSE: 115.087248
# Starting epoch 42 / 1500
# Loss: 68.903088    Validation MSE: 113.767479
# Starting epoch 43 / 1500
# Loss: 69.040116    Validation MSE: 112.658534
# Starting epoch 44 / 1500
# Loss: 63.598333    Validation MSE: 111.556113
# Starting epoch 45 / 1500
# Loss: 64.210568    Validation MSE: 110.273357
# Starting epoch 46 / 1500
# Loss: 63.210817    Validation MSE: 108.996362
# Starting epoch 47 / 1500
# Loss: 58.274825    Validation MSE: 107.699480
# Starting epoch 48 / 1500
# Loss: 58.698299    Validation MSE: 106.416794
# Starting epoch 49 / 1500
# Loss: 58.515210    Validation MSE: 105.485535
# Starting epoch 50 / 1500
# Loss: 56.559467    Validation MSE: 104.636267
# Starting epoch 51 / 1500
# Loss: 58.542058    Validation MSE: 104.086898
# Starting epoch 52 / 1500
# Loss: 57.090224    Validation MSE: 103.630331
# Starting epoch 53 / 1500
# Loss: 53.840633    Validation MSE: 103.129450
# Starting epoch 54 / 1500
# Loss: 51.884429    Validation MSE: 102.473467
# Starting epoch 55 / 1500
# Loss: 52.346527    Validation MSE: 101.267340
# Starting epoch 56 / 1500
# Loss: 54.975680    Validation MSE: 100.121280
# Starting epoch 57 / 1500
# Loss: 52.994413    Validation MSE: 99.036895
# Starting epoch 58 / 1500
# Loss: 46.930294    Validation MSE: 97.980517
# Starting epoch 59 / 1500
# Loss: 46.937723    Validation MSE: 96.903911
# Starting epoch 60 / 1500
# Loss: 47.191690    Validation MSE: 96.018482
# Starting epoch 61 / 1500
# Loss: 50.751585    Validation MSE: 95.309281
# Starting epoch 62 / 1500
# Loss: 51.942973    Validation MSE: 94.423387
# Starting epoch 63 / 1500
# Loss: 49.143480    Validation MSE: 93.668390
# Starting epoch 64 / 1500
# Loss: 53.987755    Validation MSE: 93.843354
# Starting epoch 65 / 1500
# Loss: 48.885813    Validation MSE: 93.752555
# Starting epoch 66 / 1500
# Loss: 47.116068    Validation MSE: 92.918037
# Starting epoch 67 / 1500
# Loss: 46.044400    Validation MSE: 92.121315
# Starting epoch 68 / 1500
# Loss: 42.551262    Validation MSE: 91.345371
# Starting epoch 69 / 1500
# Loss: 50.430045    Validation MSE: 91.934392
# Starting epoch 70 / 1500
# Loss: 43.957615    Validation MSE: 92.613000
# Starting epoch 71 / 1500
# Loss: 47.424745    Validation MSE: 92.071159
# Starting epoch 72 / 1500
# Loss: 45.718457    Validation MSE: 91.639727
# Starting epoch 73 / 1500
# Loss: 44.103277    Validation MSE: 91.422656
# Starting epoch 74 / 1500
# Loss: 47.276493    Validation MSE: 90.927084
# Starting epoch 75 / 1500
# Loss: 43.821273    Validation MSE: 90.188307
# Starting epoch 76 / 1500
# Loss: 49.737327    Validation MSE: 89.364103
# Starting epoch 77 / 1500
# Loss: 52.018279    Validation MSE: 88.507323
# Starting epoch 78 / 1500
# Loss: 39.795957    Validation MSE: 87.705131
# Starting epoch 79 / 1500
# Loss: 48.206308    Validation MSE: 86.948541
# Starting epoch 80 / 1500
# Loss: 39.900721    Validation MSE: 86.159313
# Starting epoch 81 / 1500
# Loss: 40.538828    Validation MSE: 85.313753
# Starting epoch 82 / 1500
# Loss: 39.305227    Validation MSE: 85.085862
# Starting epoch 83 / 1500
# Loss: 46.973104    Validation MSE: 84.889750
# Starting epoch 84 / 1500
# Loss: 41.085180    Validation MSE: 84.161018
# Starting epoch 85 / 1500
# Loss: 42.142567    Validation MSE: 83.425900
# Starting epoch 86 / 1500
# Loss: 42.589531    Validation MSE: 82.731334
# Starting epoch 87 / 1500
# Loss: 46.784956    Validation MSE: 82.129248
# Starting epoch 88 / 1500
# Loss: 39.719597    Validation MSE: 81.499721
# Starting epoch 89 / 1500
# Loss: 38.521663    Validation MSE: 80.776079
# Starting epoch 90 / 1500
# Loss: 41.736942    Validation MSE: 80.074104
# Starting epoch 91 / 1500
# Loss: 38.274372    Validation MSE: 79.379784
# Starting epoch 92 / 1500
# Loss: 39.899911    Validation MSE: 78.667654
# Starting epoch 93 / 1500
# Loss: 38.605566    Validation MSE: 78.129376
# Starting epoch 94 / 1500
# Loss: 38.666543    Validation MSE: 77.799210
# Starting epoch 95 / 1500
# Loss: 40.729477    Validation MSE: 77.473769
# Starting epoch 96 / 1500
# Loss: 39.273268    Validation MSE: 77.731686
# Starting epoch 97 / 1500
# Loss: 38.271183    Validation MSE: 77.885768
# Starting epoch 98 / 1500
# Loss: 41.204137    Validation MSE: 77.273222
# Starting epoch 99 / 1500
# Loss: 32.916171    Validation MSE: 76.641250
# Starting epoch 100 / 1500
# Loss: 38.652274    Validation MSE: 76.018129
# Starting epoch 101 / 1500
# Loss: 36.003334    Validation MSE: 75.561744
# Starting epoch 102 / 1500
# Loss: 40.208584    Validation MSE: 75.094445
# Starting epoch 103 / 1500
# Loss: 36.123011    Validation MSE: 74.576109
# Starting epoch 104 / 1500
# Loss: 38.392805    Validation MSE: 74.132091
# Starting epoch 105 / 1500
# Loss: 34.882440    Validation MSE: 73.718072
# Starting epoch 106 / 1500
# Loss: 37.890871    Validation MSE: 73.390243
# Starting epoch 107 / 1500
# Loss: 33.277965    Validation MSE: 73.031572
# Starting epoch 108 / 1500
# Loss: 35.007320    Validation MSE: 72.559057
# Starting epoch 109 / 1500
# Loss: 34.320242    Validation MSE: 72.022668
# Starting epoch 110 / 1500
# Loss: 36.559828    Validation MSE: 71.628873
# Starting epoch 111 / 1500
# Loss: 33.058951    Validation MSE: 71.279397
# Starting epoch 112 / 1500
# Loss: 32.342930    Validation MSE: 71.028926
# Starting epoch 113 / 1500
# Loss: 36.035895    Validation MSE: 70.929394
# Starting epoch 114 / 1500
# Loss: 33.017566    Validation MSE: 70.645208
# Starting epoch 115 / 1500
# Loss: 28.080312    Validation MSE: 70.212596
# Starting epoch 116 / 1500
# Loss: 33.658589    Validation MSE: 69.718837
# Starting epoch 117 / 1500
# Loss: 31.941525    Validation MSE: 69.439944
# Starting epoch 118 / 1500
# Loss: 29.676596    Validation MSE: 69.245860
# Starting epoch 119 / 1500
# Loss: 31.956359    Validation MSE: 68.839656
# Starting epoch 120 / 1500
# Loss: 35.693288    Validation MSE: 68.397768
# Starting epoch 121 / 1500
# Loss: 32.307973    Validation MSE: 68.089243
# Starting epoch 122 / 1500
# Loss: 34.620466    Validation MSE: 67.766429
# Starting epoch 123 / 1500
# Loss: 31.212801    Validation MSE: 67.451116
# Starting epoch 124 / 1500
# Loss: 27.662657    Validation MSE: 67.140289
# Starting epoch 125 / 1500
# Loss: 31.710317    Validation MSE: 66.690505
# Starting epoch 126 / 1500
# Loss: 32.673653    Validation MSE: 66.243490
# Starting epoch 127 / 1500
# Loss: 30.640837    Validation MSE: 65.807374
# Starting epoch 128 / 1500
# Loss: 28.146866    Validation MSE: 65.370209
# Starting epoch 129 / 1500
# Loss: 30.439791    Validation MSE: 65.061370
# Starting epoch 130 / 1500
# Loss: 33.295631    Validation MSE: 64.758593
# Starting epoch 131 / 1500
# Loss: 32.683211    Validation MSE: 64.356597
# Starting epoch 132 / 1500
# Loss: 30.255559    Validation MSE: 64.087406
# Starting epoch 133 / 1500
# Loss: 28.207319    Validation MSE: 63.808203
# Starting epoch 134 / 1500
# Loss: 28.206878    Validation MSE: 63.447734
# Starting epoch 135 / 1500
# Loss: 27.609028    Validation MSE: 63.104492
# Starting epoch 136 / 1500
# Loss: 27.623827    Validation MSE: 62.754475
# Starting epoch 137 / 1500
# Loss: 27.903204    Validation MSE: 62.453330
# Starting epoch 138 / 1500
# Loss: 29.265937    Validation MSE: 62.128133
# Starting epoch 139 / 1500
# Loss: 28.879586    Validation MSE: 61.755871
# Starting epoch 140 / 1500
# Loss: 29.230828    Validation MSE: 61.424184
# Starting epoch 141 / 1500
# Loss: 26.171766    Validation MSE: 61.176174
# Starting epoch 142 / 1500
# Loss: 29.346610    Validation MSE: 60.920990
# Starting epoch 143 / 1500
# Loss: 29.387164    Validation MSE: 60.598439
# Starting epoch 144 / 1500
# Loss: 26.359356    Validation MSE: 60.356071
# Starting epoch 145 / 1500
# Loss: 28.469783    Validation MSE: 60.119680
# Starting epoch 146 / 1500
# Loss: 27.814250    Validation MSE: 59.783251
# Starting epoch 147 / 1500
# Loss: 27.624761    Validation MSE: 59.436821
# Starting epoch 148 / 1500
# Loss: 28.165260    Validation MSE: 59.101777
# Starting epoch 149 / 1500
# Loss: 25.840903    Validation MSE: 58.771010
# Starting epoch 150 / 1500
# Loss: 25.374079    Validation MSE: 58.451786
# Starting epoch 151 / 1500
# Loss: 28.908107    Validation MSE: 58.164661
# Starting epoch 152 / 1500
# Loss: 28.694896    Validation MSE: 57.948834
# Starting epoch 153 / 1500
# Loss: 26.427008    Validation MSE: 57.719926
# Starting epoch 154 / 1500
# Loss: 31.620290    Validation MSE: 57.419922
# Starting epoch 155 / 1500
# Loss: 26.242721    Validation MSE: 57.197270
# Starting epoch 156 / 1500
# Loss: 27.267670    Validation MSE: 56.973917
# Starting epoch 157 / 1500
# Loss: 24.748738    Validation MSE: 56.686475
# Starting epoch 158 / 1500
# Loss: 25.921533    Validation MSE: 56.404990
# Starting epoch 159 / 1500
# Loss: 25.844721    Validation MSE: 56.175379
# Starting epoch 160 / 1500
# Loss: 26.273565    Validation MSE: 55.951413
# Starting epoch 161 / 1500
# Loss: 25.953753    Validation MSE: 55.663478
# Starting epoch 162 / 1500
# Loss: 27.262456    Validation MSE: 55.382534
# Starting epoch 163 / 1500
# Loss: 25.564992    Validation MSE: 55.350609
# Starting epoch 164 / 1500
# Loss: 25.896641    Validation MSE: 55.320167
# Starting epoch 165 / 1500
# Loss: 24.710755    Validation MSE: 55.058262
# Starting epoch 166 / 1500
# Loss: 24.452372    Validation MSE: 54.861945
# Starting epoch 167 / 1500
# Loss: 26.096675    Validation MSE: 54.783190
# Starting epoch 168 / 1500
# Loss: 24.771708    Validation MSE: 54.657384
# Starting epoch 169 / 1500
# Loss: 26.280422    Validation MSE: 54.431179
# Starting epoch 170 / 1500
# Loss: 24.639196    Validation MSE: 54.346000
# Starting epoch 171 / 1500
# Loss: 26.277867    Validation MSE: 54.271786
# Starting epoch 172 / 1500
# Loss: 24.690763    Validation MSE: 54.041028
# Starting epoch 173 / 1500
# Loss: 27.338494    Validation MSE: 53.797765
# Starting epoch 174 / 1500
# Loss: 22.550392    Validation MSE: 53.559988
# Starting epoch 175 / 1500
# Loss: 23.717939    Validation MSE: 53.326967
# Starting epoch 176 / 1500
# Loss: 24.207952    Validation MSE: 53.100354
# Starting epoch 177 / 1500
# Loss: 22.395900    Validation MSE: 52.865751
# Starting epoch 178 / 1500
# Loss: 20.456770    Validation MSE: 52.668020
# Starting epoch 179 / 1500
# Loss: 28.158224    Validation MSE: 52.570222
# Starting epoch 180 / 1500
# Loss: 27.388436    Validation MSE: 52.444143
# Starting epoch 181 / 1500
# Loss: 25.346283    Validation MSE: 52.243837
# Starting epoch 182 / 1500
# Loss: 22.470018    Validation MSE: 52.061230
# Starting epoch 183 / 1500
# Loss: 24.829928    Validation MSE: 51.857155
# Starting epoch 184 / 1500
# Loss: 23.257292    Validation MSE: 51.632640
# Starting epoch 185 / 1500
# Loss: 24.168765    Validation MSE: 51.471455
# Starting epoch 186 / 1500
# Loss: 25.297362    Validation MSE: 51.333013
# Starting epoch 187 / 1500
# Loss: 25.949589    Validation MSE: 51.132666
# Starting epoch 188 / 1500
# Loss: 26.319960    Validation MSE: 50.937143
# Starting epoch 189 / 1500
# Loss: 24.251278    Validation MSE: 50.740654
# Starting epoch 190 / 1500
# Loss: 20.839350    Validation MSE: 50.529838
# Starting epoch 191 / 1500
# Loss: 26.284488    Validation MSE: 50.322046
# Starting epoch 192 / 1500
# Loss: 21.354681    Validation MSE: 50.104740
# Starting epoch 193 / 1500
# Loss: 26.489929    Validation MSE: 49.917254
# Starting epoch 194 / 1500
# Loss: 22.527818    Validation MSE: 49.732826
# Starting epoch 195 / 1500
# Loss: 22.946735    Validation MSE: 49.519594
# Starting epoch 196 / 1500
# Loss: 23.646457    Validation MSE: 49.345403
# Starting epoch 197 / 1500
# Loss: 22.905748    Validation MSE: 49.228641
# Starting epoch 198 / 1500
# Loss: 25.207445    Validation MSE: 49.083816
# Starting epoch 199 / 1500
# Loss: 21.677035    Validation MSE: 48.892737
# Starting epoch 200 / 1500
# Loss: 20.537907    Validation MSE: 48.702723
# Starting epoch 201 / 1500
# Loss: 25.525363    Validation MSE: 48.528117
# Starting epoch 202 / 1500
# Loss: 22.572594    Validation MSE: 48.361844
# Starting epoch 203 / 1500
# Loss: 22.277225    Validation MSE: 48.202988
# Starting epoch 204 / 1500
# Loss: 23.844604    Validation MSE: 48.031711
# Starting epoch 205 / 1500
# Loss: 24.044550    Validation MSE: 47.836786
# Starting epoch 206 / 1500
# Loss: 20.951112    Validation MSE: 47.680553
# Starting epoch 207 / 1500
# Loss: 22.931007    Validation MSE: 47.524352
# Starting epoch 208 / 1500
# Loss: 21.319217    Validation MSE: 47.347121
# Starting epoch 209 / 1500
# Loss: 21.078563    Validation MSE: 47.171599
# Starting epoch 210 / 1500
# Loss: 20.981307    Validation MSE: 46.991541
# Starting epoch 211 / 1500
# Loss: 22.152552    Validation MSE: 46.819382
# Starting epoch 212 / 1500
# Loss: 20.805910    Validation MSE: 46.670522
# Starting epoch 213 / 1500
# Loss: 25.002143    Validation MSE: 46.592539
# Starting epoch 214 / 1500
# Loss: 21.988230    Validation MSE: 46.504973
# Starting epoch 215 / 1500
# Loss: 21.878591    Validation MSE: 46.370789
# Starting epoch 216 / 1500
# Loss: 21.106506    Validation MSE: 46.219700
# Starting epoch 217 / 1500
# Loss: 21.830717    Validation MSE: 46.051981
# Starting epoch 218 / 1500
# Loss: 22.024616    Validation MSE: 45.881426
# Starting epoch 219 / 1500
# Loss: 22.647059    Validation MSE: 45.816144
# Starting epoch 220 / 1500
# Loss: 20.894992    Validation MSE: 45.750188
# Starting epoch 221 / 1500
# Loss: 22.462881    Validation MSE: 45.578103
# Starting epoch 222 / 1500
# Loss: 20.926817    Validation MSE: 45.406229
# Starting epoch 223 / 1500
# Loss: 20.648262    Validation MSE: 45.237411
# Starting epoch 224 / 1500
# Loss: 21.117520    Validation MSE: 45.077491
# Starting epoch 225 / 1500
# Loss: 22.278626    Validation MSE: 44.948382
# Starting epoch 226 / 1500
# Loss: 23.893043    Validation MSE: 44.811432
# Starting epoch 227 / 1500
# Loss: 21.058442    Validation MSE: 44.644471
# Starting epoch 228 / 1500
# Loss: 21.347570    Validation MSE: 44.482873
# Starting epoch 229 / 1500
# Loss: 20.727605    Validation MSE: 44.376827
# Starting epoch 230 / 1500
# Loss: 22.350950    Validation MSE: 44.284715
# Starting epoch 231 / 1500
# Loss: 21.152950    Validation MSE: 44.147310
# Starting epoch 232 / 1500
# Loss: 20.297353    Validation MSE: 44.031361
# Starting epoch 233 / 1500
# Loss: 22.725107    Validation MSE: 43.911353
# Starting epoch 234 / 1500
# Loss: 22.110446    Validation MSE: 43.756337
# Starting epoch 235 / 1500
# Loss: 18.708031    Validation MSE: 43.610381
# Starting epoch 236 / 1500
# Loss: 21.987873    Validation MSE: 43.478560
# Starting epoch 237 / 1500
# Loss: 22.519163    Validation MSE: 43.337310
# Starting epoch 238 / 1500
# Loss: 20.577780    Validation MSE: 43.184242
# Starting epoch 239 / 1500
# Loss: 22.148184    Validation MSE: 43.048107
# Starting epoch 240 / 1500
# Loss: 22.693837    Validation MSE: 42.991935
# Starting epoch 241 / 1500
# Loss: 21.535086    Validation MSE: 42.927677
# Starting epoch 242 / 1500
# Loss: 19.388112    Validation MSE: 42.862246
# Starting epoch 243 / 1500
# Loss: 21.092125    Validation MSE: 42.797463
# Starting epoch 244 / 1500
# Loss: 22.082279    Validation MSE: 42.660039
# Starting epoch 245 / 1500
# Loss: 20.409574    Validation MSE: 42.519915
# Starting epoch 246 / 1500
# Loss: 21.806396    Validation MSE: 42.383067
# Starting epoch 247 / 1500
# Loss: 19.356679    Validation MSE: 42.245551
# Starting epoch 248 / 1500
# Loss: 20.545523    Validation MSE: 42.104333
# Starting epoch 249 / 1500
# Loss: 20.925185    Validation MSE: 42.129440
# Starting epoch 250 / 1500
# Loss: 21.369842    Validation MSE: 42.189565
# Starting epoch 251 / 1500
# Loss: 20.937650    Validation MSE: 42.095818
# Starting epoch 252 / 1500
# Loss: 19.676807    Validation MSE: 41.971412
# Starting epoch 253 / 1500
# Loss: 19.683872    Validation MSE: 41.857244
# Starting epoch 254 / 1500
# Loss: 19.608093    Validation MSE: 41.737002
# Starting epoch 255 / 1500
# Loss: 18.907598    Validation MSE: 41.602094
# Starting epoch 256 / 1500
# Loss: 21.422749    Validation MSE: 41.480746
# Starting epoch 257 / 1500
# Loss: 21.615438    Validation MSE: 41.364768
# Starting epoch 258 / 1500
# Loss: 21.320235    Validation MSE: 41.247932
# Starting epoch 259 / 1500
# Loss: 20.979810    Validation MSE: 41.129725
# Starting epoch 260 / 1500
# Loss: 19.246131    Validation MSE: 41.002319
# Starting epoch 261 / 1500
# Loss: 19.851873    Validation MSE: 40.875112
# Starting epoch 262 / 1500
# Loss: 21.073285    Validation MSE: 40.746987
# Starting epoch 263 / 1500
# Loss: 21.173124    Validation MSE: 40.626023
# Starting epoch 264 / 1500
# Loss: 19.989992    Validation MSE: 40.511110
# Starting epoch 265 / 1500
# Loss: 19.332746    Validation MSE: 40.430642
# Starting epoch 266 / 1500
# Loss: 21.026845    Validation MSE: 40.390387
# Starting epoch 267 / 1500
# Loss: 19.582499    Validation MSE: 40.311831
# Starting epoch 268 / 1500
# Loss: 21.298327    Validation MSE: 40.189945
# Starting epoch 269 / 1500
# Loss: 19.322787    Validation MSE: 40.064918
# Starting epoch 270 / 1500
# Loss: 20.375120    Validation MSE: 39.940526
# Starting epoch 271 / 1500
# Loss: 20.878034    Validation MSE: 39.817259
# Starting epoch 272 / 1500
# Loss: 21.078661    Validation MSE: 39.697703
# Starting epoch 273 / 1500
# Loss: 19.656227    Validation MSE: 39.582617
# Starting epoch 274 / 1500
# Loss: 21.308353    Validation MSE: 39.468356
# Starting epoch 275 / 1500
# Loss: 18.446711    Validation MSE: 39.357749
# Starting epoch 276 / 1500
# Loss: 21.325019    Validation MSE: 39.243536
# Starting epoch 277 / 1500
# Loss: 20.188036    Validation MSE: 39.143450
# Starting epoch 278 / 1500
# Loss: 19.949387    Validation MSE: 39.048510
# Starting epoch 279 / 1500
# Loss: 19.621878    Validation MSE: 39.036079
# Starting epoch 280 / 1500
# Loss: 21.378459    Validation MSE: 39.020076
# Starting epoch 281 / 1500
# Loss: 19.438592    Validation MSE: 38.906909
# Starting epoch 282 / 1500
# Loss: 18.908261    Validation MSE: 38.794692
# Starting epoch 283 / 1500
# Loss: 19.609598    Validation MSE: 38.680618
# Starting epoch 284 / 1500
# Loss: 20.247224    Validation MSE: 38.568108
# Starting epoch 285 / 1500
# Loss: 19.320600    Validation MSE: 38.461040
# Starting epoch 286 / 1500
# Loss: 19.336293    Validation MSE: 38.354015
# Starting epoch 287 / 1500
# Loss: 18.608879    Validation MSE: 38.247295
# Starting epoch 288 / 1500
# Loss: 18.349488    Validation MSE: 38.141535
# Starting epoch 289 / 1500
# Loss: 19.074785    Validation MSE: 38.059415
# Starting epoch 290 / 1500
# Loss: 20.522138    Validation MSE: 37.986160
# Starting epoch 291 / 1500
# Loss: 19.192866    Validation MSE: 37.917391
# Starting epoch 292 / 1500
# Loss: 20.394742    Validation MSE: 37.842830
# Starting epoch 293 / 1500
# Loss: 19.252781    Validation MSE: 37.745834
# Starting epoch 294 / 1500
# Loss: 18.161272    Validation MSE: 37.648536
# Starting epoch 295 / 1500
# Loss: 19.778529    Validation MSE: 37.543741
# Starting epoch 296 / 1500
# Loss: 20.789796    Validation MSE: 37.439020
# Starting epoch 297 / 1500
# Loss: 18.142637    Validation MSE: 37.342231
# Starting epoch 298 / 1500
# Loss: 20.681640    Validation MSE: 37.288597
# Starting epoch 299 / 1500
# Loss: 20.534337    Validation MSE: 37.231731
# Starting epoch 300 / 1500
# Loss: 18.821533    Validation MSE: 37.131529
# Starting epoch 301 / 1500
# Loss: 20.071969    Validation MSE: 37.029495
# Starting epoch 302 / 1500
# Loss: 20.019030    Validation MSE: 36.928824
# Starting epoch 303 / 1500
# Loss: 19.750981    Validation MSE: 36.868845
# Starting epoch 304 / 1500
# Loss: 18.839860    Validation MSE: 36.810865
# Starting epoch 305 / 1500
# Loss: 21.501499    Validation MSE: 36.722629
# Starting epoch 306 / 1500
# Loss: 18.659380    Validation MSE: 36.635627
# Starting epoch 307 / 1500
# Loss: 18.838773    Validation MSE: 36.541258
# Starting epoch 308 / 1500
# Loss: 18.520359    Validation MSE: 36.449513
# Starting epoch 309 / 1500
# Loss: 18.961237    Validation MSE: 36.363499
# Starting epoch 310 / 1500
# Loss: 19.321723    Validation MSE: 36.303601
# Starting epoch 311 / 1500
# Loss: 18.679516    Validation MSE: 36.254047
# Starting epoch 312 / 1500
# Loss: 19.855318    Validation MSE: 36.209929
# Starting epoch 313 / 1500
# Loss: 18.997446    Validation MSE: 36.150069
# Starting epoch 314 / 1500
# Loss: 18.154462    Validation MSE: 36.057235
# Starting epoch 315 / 1500
# Loss: 19.288498    Validation MSE: 35.965283
# Starting epoch 316 / 1500
# Loss: 18.680148    Validation MSE: 35.880980
# Starting epoch 317 / 1500
# Loss: 19.540194    Validation MSE: 35.801113
# Starting epoch 318 / 1500
# Loss: 17.630346    Validation MSE: 35.714657
# Starting epoch 319 / 1500
# Loss: 18.804684    Validation MSE: 35.625289
# Starting epoch 320 / 1500
# Loss: 19.685445    Validation MSE: 35.534844
# Starting epoch 321 / 1500
# Loss: 19.180302    Validation MSE: 35.443538
# Starting epoch 322 / 1500
# Loss: 18.705010    Validation MSE: 35.361980
# Starting epoch 323 / 1500
# Loss: 18.409471    Validation MSE: 35.284390
# Starting epoch 324 / 1500
# Loss: 17.911216    Validation MSE: 35.201661
# Starting epoch 325 / 1500
# Loss: 19.588116    Validation MSE: 35.120279
# Starting epoch 326 / 1500
# Loss: 18.981695    Validation MSE: 35.065873
# Starting epoch 327 / 1500
# Loss: 18.021875    Validation MSE: 35.007980
# Starting epoch 328 / 1500
# Loss: 17.174710    Validation MSE: 34.936938
# Starting epoch 329 / 1500
# Loss: 18.947309    Validation MSE: 34.878303
# Starting epoch 330 / 1500
# Loss: 18.269428    Validation MSE: 34.804576
# Starting epoch 331 / 1500
# Loss: 17.968256    Validation MSE: 34.726254
# Starting epoch 332 / 1500
# Loss: 17.324901    Validation MSE: 34.684392
# Starting epoch 333 / 1500
# Loss: 19.029555    Validation MSE: 34.638176
# Starting epoch 334 / 1500
# Loss: 19.028015    Validation MSE: 34.566953
# Starting epoch 335 / 1500
# Loss: 18.322993    Validation MSE: 34.500494
# Starting epoch 336 / 1500
# Loss: 18.651580    Validation MSE: 34.424781
# Starting epoch 337 / 1500
# Loss: 17.401853    Validation MSE: 34.342760
# Starting epoch 338 / 1500
# Loss: 17.853953    Validation MSE: 34.267099
# Starting epoch 339 / 1500
# Loss: 18.887344    Validation MSE: 34.194934
# Starting epoch 340 / 1500
# Loss: 17.945736    Validation MSE: 34.125967
# Starting epoch 341 / 1500
# Loss: 18.784068    Validation MSE: 34.052813
# Starting epoch 342 / 1500
# Loss: 18.072335    Validation MSE: 33.975552
# Starting epoch 343 / 1500
# Loss: 19.217933    Validation MSE: 33.903087
# Starting epoch 344 / 1500
# Loss: 18.564590    Validation MSE: 33.855263
# Starting epoch 345 / 1500
# Loss: 19.458305    Validation MSE: 33.803484
# Starting epoch 346 / 1500
# Loss: 18.336636    Validation MSE: 33.724133
# Starting epoch 347 / 1500
# Loss: 17.411078    Validation MSE: 33.647237
# Starting epoch 348 / 1500
# Loss: 17.708924    Validation MSE: 33.572958
# Starting epoch 349 / 1500
# Loss: 18.118873    Validation MSE: 33.500362
# Starting epoch 350 / 1500
# Loss: 18.358266    Validation MSE: 33.427547
# Starting epoch 351 / 1500
# Loss: 19.869662    Validation MSE: 33.355173
# Starting epoch 352 / 1500
# Loss: 17.571073    Validation MSE: 33.286892
# Starting epoch 353 / 1500
# Loss: 19.091857    Validation MSE: 33.237221
# Starting epoch 354 / 1500
# Loss: 19.106619    Validation MSE: 33.184369
# Starting epoch 355 / 1500
# Loss: 18.280671    Validation MSE: 33.125820
# Starting epoch 356 / 1500
# Loss: 17.119278    Validation MSE: 33.071745
# Starting epoch 357 / 1500
# Loss: 17.988747    Validation MSE: 33.001624
# Starting epoch 358 / 1500
# Loss: 18.402526    Validation MSE: 32.941174
# Starting epoch 359 / 1500
# Loss: 17.721829    Validation MSE: 32.889842
# Starting epoch 360 / 1500
# Loss: 19.002225    Validation MSE: 32.829379
# Starting epoch 361 / 1500
# Loss: 19.481676    Validation MSE: 32.759991
# Starting epoch 362 / 1500
# Loss: 17.675407    Validation MSE: 32.686407
# Starting epoch 363 / 1500
# Loss: 17.096517    Validation MSE: 32.616694
# Starting epoch 364 / 1500
# Loss: 17.949475    Validation MSE: 32.547621
# Starting epoch 365 / 1500
# Loss: 18.190631    Validation MSE: 32.484431
# Starting epoch 366 / 1500
# Loss: 18.116133    Validation MSE: 32.422168
# Starting epoch 367 / 1500
# Loss: 18.592535    Validation MSE: 32.354632
# Starting epoch 368 / 1500
# Loss: 17.026777    Validation MSE: 32.287318
# Starting epoch 369 / 1500
# Loss: 18.436670    Validation MSE: 32.216279
# Starting epoch 370 / 1500
# Loss: 19.106215    Validation MSE: 32.147893
# Starting epoch 371 / 1500
# Loss: 18.224792    Validation MSE: 32.081377
# Starting epoch 372 / 1500
# Loss: 19.063130    Validation MSE: 32.013149
# Starting epoch 373 / 1500
# Loss: 18.751363    Validation MSE: 31.949954
# Starting epoch 374 / 1500
# Loss: 17.165944    Validation MSE: 31.886515
# Starting epoch 375 / 1500
# Loss: 18.388815    Validation MSE: 31.817683
# Starting epoch 376 / 1500
# Loss: 17.709975    Validation MSE: 31.758406
# Starting epoch 377 / 1500
# Loss: 18.615495    Validation MSE: 31.719975
# Starting epoch 378 / 1500
# Loss: 19.323763    Validation MSE: 31.672075
# Starting epoch 379 / 1500
# Loss: 18.897498    Validation MSE: 31.607324
# Starting epoch 380 / 1500
# Loss: 18.510817    Validation MSE: 31.543802
# Starting epoch 381 / 1500
# Loss: 17.963593    Validation MSE: 31.481415
# Starting epoch 382 / 1500
# Loss: 18.541920    Validation MSE: 31.418724
# Starting epoch 383 / 1500
# Loss: 18.174032    Validation MSE: 31.354987
# Starting epoch 384 / 1500
# Loss: 17.529411    Validation MSE: 31.293928
# Starting epoch 385 / 1500
# Loss: 18.017830    Validation MSE: 31.233566
# Starting epoch 386 / 1500
# Loss: 17.274940    Validation MSE: 31.171620
# Starting epoch 387 / 1500
# Loss: 17.351381    Validation MSE: 31.107538
# Starting epoch 388 / 1500
# Loss: 19.622143    Validation MSE: 31.047203
# Starting epoch 389 / 1500
# Loss: 17.572850    Validation MSE: 30.992112
# Starting epoch 390 / 1500
# Loss: 19.108958    Validation MSE: 30.936662
# Starting epoch 391 / 1500
# Loss: 17.197760    Validation MSE: 30.876093
# Starting epoch 392 / 1500
# Loss: 17.487769    Validation MSE: 30.816207
# Starting epoch 393 / 1500
# Loss: 17.723891    Validation MSE: 30.757431
# Starting epoch 394 / 1500
# Loss: 17.225931    Validation MSE: 30.697544
# Starting epoch 395 / 1500
# Loss: 17.810860    Validation MSE: 30.636740
# Starting epoch 396 / 1500
# Loss: 17.080840    Validation MSE: 30.581702
# Starting epoch 397 / 1500
# Loss: 17.458495    Validation MSE: 30.529079
# Starting epoch 398 / 1500
# Loss: 17.614026    Validation MSE: 30.470533
# Starting epoch 399 / 1500
# Loss: 18.056219    Validation MSE: 30.410787
# Starting epoch 400 / 1500
# Loss: 17.540923    Validation MSE: 30.351591
# Starting epoch 401 / 1500
# Loss: 17.711520    Validation MSE: 30.291316
# Starting epoch 402 / 1500
# Loss: 18.408149    Validation MSE: 30.231558
# Starting epoch 403 / 1500
# Loss: 17.733524    Validation MSE: 30.171918
# Starting epoch 404 / 1500
# Loss: 17.976617    Validation MSE: 30.127656
# Starting epoch 405 / 1500
# Loss: 17.776618    Validation MSE: 30.090557
# Starting epoch 406 / 1500
# Loss: 18.458264    Validation MSE: 30.037925
# Starting epoch 407 / 1500
# Loss: 17.931302    Validation MSE: 29.983275
# Starting epoch 408 / 1500
# Loss: 17.523889    Validation MSE: 29.947516
# Starting epoch 409 / 1500
# Loss: 19.493114    Validation MSE: 29.911556
# Starting epoch 410 / 1500
# Loss: 17.741653    Validation MSE: 29.860290
# Starting epoch 411 / 1500
# Loss: 17.278026    Validation MSE: 29.806203
# Starting epoch 412 / 1500
# Loss: 18.004744    Validation MSE: 29.753014
# Starting epoch 413 / 1500
# Loss: 18.051566    Validation MSE: 29.703817
# Starting epoch 414 / 1500
# Loss: 17.967949    Validation MSE: 29.651046
# Starting epoch 415 / 1500
# Loss: 18.000350    Validation MSE: 29.594059
# Starting epoch 416 / 1500
# Loss: 18.045464    Validation MSE: 29.537695
# Starting epoch 417 / 1500
# Loss: 17.918870    Validation MSE: 29.485099
# Starting epoch 418 / 1500
# Loss: 18.552146    Validation MSE: 29.436537
# Starting epoch 419 / 1500
# Loss: 17.685775    Validation MSE: 29.388586
# Starting epoch 420 / 1500
# Loss: 18.138380    Validation MSE: 29.336649
# Starting epoch 421 / 1500
# Loss: 17.280204    Validation MSE: 29.281171
# Starting epoch 422 / 1500
# Loss: 18.392437    Validation MSE: 29.275788
# Starting epoch 423 / 1500
# Loss: 19.800619    Validation MSE: 29.270130
# Starting epoch 424 / 1500
# Loss: 18.646113    Validation MSE: 29.250550
# Starting epoch 425 / 1500
# Loss: 16.925857    Validation MSE: 29.246769
# Starting epoch 426 / 1500
# Loss: 17.202735    Validation MSE: 29.210474
# Starting epoch 427 / 1500
# Loss: 17.022861    Validation MSE: 29.166222
# Starting epoch 428 / 1500
# Loss: 17.570448    Validation MSE: 29.120216
# Starting epoch 429 / 1500
# Loss: 16.691015    Validation MSE: 29.067216
# Starting epoch 430 / 1500
# Loss: 17.286697    Validation MSE: 29.016035
# Starting epoch 431 / 1500
# Loss: 17.456083    Validation MSE: 28.969486
# Starting epoch 432 / 1500
# Loss: 17.391049    Validation MSE: 28.925585
# Starting epoch 433 / 1500
# Loss: 17.508427    Validation MSE: 28.880299
# Starting epoch 434 / 1500
# Loss: 17.389420    Validation MSE: 28.836221
# Starting epoch 435 / 1500
# Loss: 16.860602    Validation MSE: 28.793612
# Starting epoch 436 / 1500
# Loss: 17.058794    Validation MSE: 28.765599
# Starting epoch 437 / 1500
# Loss: 17.638425    Validation MSE: 28.735495
# Starting epoch 438 / 1500
# Loss: 16.935271    Validation MSE: 28.686638
# Starting epoch 439 / 1500
# Loss: 17.478098    Validation MSE: 28.647093
# Starting epoch 440 / 1500
# Loss: 16.407408    Validation MSE: 28.611516
# Starting epoch 441 / 1500
# Loss: 16.731424    Validation MSE: 28.571993
# Starting epoch 442 / 1500
# Loss: 17.641711    Validation MSE: 28.532545
# Starting epoch 443 / 1500
# Loss: 17.299017    Validation MSE: 28.485964
# Starting epoch 444 / 1500
# Loss: 18.203031    Validation MSE: 28.435339
# Starting epoch 445 / 1500
# Loss: 17.501866    Validation MSE: 28.385996
# Starting epoch 446 / 1500
# Loss: 17.556999    Validation MSE: 28.354283
# Starting epoch 447 / 1500
# Loss: 16.935425    Validation MSE: 28.323718
# Starting epoch 448 / 1500
# Loss: 17.409867    Validation MSE: 28.275222
# Starting epoch 449 / 1500
# Loss: 18.148749    Validation MSE: 28.233470
# Starting epoch 450 / 1500
# Loss: 17.296636    Validation MSE: 28.200103
# Starting epoch 451 / 1500
# Loss: 18.346378    Validation MSE: 28.160419
# Starting epoch 452 / 1500
# Loss: 18.233296    Validation MSE: 28.117617
# Starting epoch 453 / 1500
# Loss: 17.189277    Validation MSE: 28.080442
# Starting epoch 454 / 1500
# Loss: 17.099630    Validation MSE: 28.040156
# Starting epoch 455 / 1500
# Loss: 16.896554    Validation MSE: 27.992963
# Starting epoch 456 / 1500
# Loss: 17.019022    Validation MSE: 27.950190
# Starting epoch 457 / 1500
# Loss: 17.456893    Validation MSE: 27.907630
# Starting epoch 458 / 1500
# Loss: 18.000463    Validation MSE: 27.862353
# Starting epoch 459 / 1500
# Loss: 17.928741    Validation MSE: 27.818056
# Starting epoch 460 / 1500
# Loss: 18.121597    Validation MSE: 27.774198
# Starting epoch 461 / 1500
# Loss: 18.447798    Validation MSE: 27.733744
# Starting epoch 462 / 1500
# Loss: 17.173190    Validation MSE: 27.692347
# Starting epoch 463 / 1500
# Loss: 17.029559    Validation MSE: 27.658840
# Starting epoch 464 / 1500
# Loss: 16.968913    Validation MSE: 27.625630
# Starting epoch 465 / 1500
# Loss: 16.955224    Validation MSE: 27.586186
# Starting epoch 466 / 1500
# Loss: 17.564845    Validation MSE: 27.547891
# Starting epoch 467 / 1500
# Loss: 16.833750    Validation MSE: 27.508235
# Starting epoch 468 / 1500
# Loss: 16.861455    Validation MSE: 27.467686
# Starting epoch 469 / 1500
# Loss: 17.566129    Validation MSE: 27.424094
# Starting epoch 470 / 1500
# Loss: 16.352704    Validation MSE: 27.380571
# Starting epoch 471 / 1500
# Loss: 17.516005    Validation MSE: 27.340020
# Starting epoch 472 / 1500
# Loss: 18.228611    Validation MSE: 27.299732
# Starting epoch 473 / 1500
# Loss: 17.109929    Validation MSE: 27.256838
# Starting epoch 474 / 1500
# Loss: 17.609300    Validation MSE: 27.213610
# Starting epoch 475 / 1500
# Loss: 16.939095    Validation MSE: 27.169551
# Starting epoch 476 / 1500
# Loss: 16.653102    Validation MSE: 27.143463
# Starting epoch 477 / 1500
# Loss: 16.844156    Validation MSE: 27.118079
# Starting epoch 478 / 1500
# Loss: 16.719826    Validation MSE: 27.075010
# Starting epoch 479 / 1500
# Loss: 17.388299    Validation MSE: 27.032650
# Starting epoch 480 / 1500
# Loss: 17.387936    Validation MSE: 26.989817
# Starting epoch 481 / 1500
# Loss: 17.079578    Validation MSE: 26.946368
# Starting epoch 482 / 1500
# Loss: 17.019366    Validation MSE: 26.904326
# Starting epoch 483 / 1500
# Loss: 17.417050    Validation MSE: 26.862279
# Starting epoch 484 / 1500
# Loss: 17.111118    Validation MSE: 26.819753
# Starting epoch 485 / 1500
# Loss: 17.694414    Validation MSE: 26.787593
# Starting epoch 486 / 1500
# Loss: 17.349321    Validation MSE: 26.754930
# Starting epoch 487 / 1500
# Loss: 16.829351    Validation MSE: 26.712454
# Starting epoch 488 / 1500
# Loss: 17.208790    Validation MSE: 26.671645
# Starting epoch 489 / 1500
# Loss: 17.468208    Validation MSE: 26.645031
# Starting epoch 490 / 1500
# Loss: 16.648094    Validation MSE: 26.618979
# Starting epoch 491 / 1500
# Loss: 16.535747    Validation MSE: 26.582943
# Starting epoch 492 / 1500
# Loss: 16.508214    Validation MSE: 26.564328
# Starting epoch 493 / 1500
# Loss: 17.356715    Validation MSE: 26.542897
# Starting epoch 494 / 1500
# Loss: 17.467603    Validation MSE: 26.503664
# Starting epoch 495 / 1500
# Loss: 17.265317    Validation MSE: 26.486632
# Starting epoch 496 / 1500
# Loss: 17.274626    Validation MSE: 26.468578
# Starting epoch 497 / 1500
# Loss: 16.942539    Validation MSE: 26.428997
# Starting epoch 498 / 1500
# Loss: 17.373443    Validation MSE: 26.392307
# Starting epoch 499 / 1500
# Loss: 17.144050    Validation MSE: 26.354270
# Starting epoch 500 / 1500
# Loss: 16.819308    Validation MSE: 26.313230
# Starting epoch 501 / 1500
# Loss: 16.395916    Validation MSE: 26.273527
# Starting epoch 502 / 1500
# Loss: 17.126100    Validation MSE: 26.236292
# Starting epoch 503 / 1500
# Loss: 16.389666    Validation MSE: 26.212890
# Starting epoch 504 / 1500
# Loss: 17.169130    Validation MSE: 26.187098
# Starting epoch 505 / 1500
# Loss: 17.632855    Validation MSE: 26.148019
# Starting epoch 506 / 1500
# Loss: 16.827295    Validation MSE: 26.110180
# Starting epoch 507 / 1500
# Loss: 16.036213    Validation MSE: 26.074801
# Starting epoch 508 / 1500
# Loss: 17.650808    Validation MSE: 26.041235
# Starting epoch 509 / 1500
# Loss: 17.211516    Validation MSE: 26.004889
# Starting epoch 510 / 1500
# Loss: 16.526519    Validation MSE: 25.967749
# Starting epoch 511 / 1500
# Loss: 17.141808    Validation MSE: 25.931096
# Starting epoch 512 / 1500
# Loss: 18.430468    Validation MSE: 25.892816
# Starting epoch 513 / 1500
# Loss: 17.858193    Validation MSE: 25.859100
# Starting epoch 514 / 1500
# Loss: 17.017252    Validation MSE: 25.827609
# Starting epoch 515 / 1500
# Loss: 17.655841    Validation MSE: 25.790621
# Starting epoch 516 / 1500
# Loss: 16.428263    Validation MSE: 25.755650
# Starting epoch 517 / 1500
# Loss: 16.011693    Validation MSE: 25.724498
# Starting epoch 518 / 1500
# Loss: 16.465372    Validation MSE: 25.689421
# Starting epoch 519 / 1500
# Loss: 17.612049    Validation MSE: 25.653144
# Starting epoch 520 / 1500
# Loss: 17.251198    Validation MSE: 25.618592
# Starting epoch 521 / 1500
# Loss: 16.299984    Validation MSE: 25.582325
# Starting epoch 522 / 1500
# Loss: 16.926674    Validation MSE: 25.544710
# Starting epoch 523 / 1500
# Loss: 17.292834    Validation MSE: 25.507808
# Starting epoch 524 / 1500
# Loss: 16.619300    Validation MSE: 25.471854
# Starting epoch 525 / 1500
# Loss: 16.970127    Validation MSE: 25.435996
# Starting epoch 526 / 1500
# Loss: 16.442769    Validation MSE: 25.405947
# Starting epoch 527 / 1500
# Loss: 17.383153    Validation MSE: 25.377450
# Starting epoch 528 / 1500
# Loss: 16.961521    Validation MSE: 25.353469
# Starting epoch 529 / 1500
# Loss: 16.510147    Validation MSE: 25.329805
# Starting epoch 530 / 1500
# Loss: 16.452777    Validation MSE: 25.298839
# Starting epoch 531 / 1500
# Loss: 15.989617    Validation MSE: 25.265280
# Starting epoch 532 / 1500
# Loss: 17.403063    Validation MSE: 25.230181
# Starting epoch 533 / 1500
# Loss: 16.658732    Validation MSE: 25.195013
# Starting epoch 534 / 1500
# Loss: 16.351294    Validation MSE: 25.161581
# Starting epoch 535 / 1500
# Loss: 16.623678    Validation MSE: 25.139668
# Starting epoch 536 / 1500
# Loss: 16.389346    Validation MSE: 25.117706
# Starting epoch 537 / 1500
# Loss: 16.925591    Validation MSE: 25.083795
# Starting epoch 538 / 1500
# Loss: 16.488067    Validation MSE: 25.048432
# Starting epoch 539 / 1500
# Loss: 16.499933    Validation MSE: 25.015712
# Starting epoch 540 / 1500
# Loss: 16.856305    Validation MSE: 24.983066
# Starting epoch 541 / 1500
# Loss: 16.249774    Validation MSE: 24.958008
# Starting epoch 542 / 1500
# Loss: 16.925507    Validation MSE: 24.933722
# Starting epoch 543 / 1500
# Loss: 16.406368    Validation MSE: 24.899104
# Starting epoch 544 / 1500
# Loss: 16.946205    Validation MSE: 24.867649
# Starting epoch 545 / 1500
# Loss: 16.015599    Validation MSE: 24.836916
# Starting epoch 546 / 1500
# Loss: 16.978612    Validation MSE: 24.802938
# Starting epoch 547 / 1500
# Loss: 16.890983    Validation MSE: 24.778477
# Starting epoch 548 / 1500
# Loss: 16.335597    Validation MSE: 24.754297
# Starting epoch 549 / 1500
# Loss: 17.406431    Validation MSE: 24.721571
# Starting epoch 550 / 1500
# Loss: 16.642140    Validation MSE: 24.689476
# Starting epoch 551 / 1500
# Loss: 16.612535    Validation MSE: 24.655835
# Starting epoch 552 / 1500
# Loss: 17.207277    Validation MSE: 24.623279
# Starting epoch 553 / 1500
# Loss: 17.357721    Validation MSE: 24.590869
# Starting epoch 554 / 1500
# Loss: 16.716472    Validation MSE: 24.557184
# Starting epoch 555 / 1500
# Loss: 16.895407    Validation MSE: 24.524177
# Starting epoch 556 / 1500
# Loss: 16.451841    Validation MSE: 24.491171
# Starting epoch 557 / 1500
# Loss: 16.700203    Validation MSE: 24.458964
# Starting epoch 558 / 1500
# Loss: 17.177293    Validation MSE: 24.427042
# Starting epoch 559 / 1500
# Loss: 16.872166    Validation MSE: 24.394548
# Starting epoch 560 / 1500
# Loss: 16.681866    Validation MSE: 24.363017
# Starting epoch 561 / 1500
# Loss: 16.161071    Validation MSE: 24.342837
# Starting epoch 562 / 1500
# Loss: 16.344776    Validation MSE: 24.322176
# Starting epoch 563 / 1500
# Loss: 16.704805    Validation MSE: 24.289804
# Starting epoch 564 / 1500
# Loss: 17.064076    Validation MSE: 24.257551
# Starting epoch 565 / 1500
# Loss: 16.605916    Validation MSE: 24.259332
# Starting epoch 566 / 1500
# Loss: 17.351237    Validation MSE: 24.261518
# Starting epoch 567 / 1500
# Loss: 16.959295    Validation MSE: 24.230742
# Starting epoch 568 / 1500
# Loss: 16.834874    Validation MSE: 24.200137
# Starting epoch 569 / 1500
# Loss: 16.648020    Validation MSE: 24.168344
# Starting epoch 570 / 1500
# Loss: 17.256706    Validation MSE: 24.136885
# Starting epoch 571 / 1500
# Loss: 16.513007    Validation MSE: 24.105847
# Starting epoch 572 / 1500
# Loss: 16.645478    Validation MSE: 24.075796
# Starting epoch 573 / 1500
# Loss: 16.823976    Validation MSE: 24.054264
# Starting epoch 574 / 1500
# Loss: 16.415410    Validation MSE: 24.035209
# Starting epoch 575 / 1500
# Loss: 16.555843    Validation MSE: 24.006647
# Starting epoch 576 / 1500
# Loss: 16.542278    Validation MSE: 23.976559
# Starting epoch 577 / 1500
# Loss: 16.886779    Validation MSE: 23.946918
# Starting epoch 578 / 1500
# Loss: 17.650891    Validation MSE: 23.917838
# Starting epoch 579 / 1500
# Loss: 16.563350    Validation MSE: 23.890311
# Starting epoch 580 / 1500
# Loss: 16.497312    Validation MSE: 23.863855
# Starting epoch 581 / 1500
# Loss: 16.290783    Validation MSE: 23.842037
# Starting epoch 582 / 1500
# Loss: 16.582704    Validation MSE: 23.820129
# Starting epoch 583 / 1500
# Loss: 15.736153    Validation MSE: 23.793801
# Starting epoch 584 / 1500
# Loss: 17.579372    Validation MSE: 23.769905
# Starting epoch 585 / 1500
# Loss: 17.070328    Validation MSE: 23.744776
# Starting epoch 586 / 1500
# Loss: 16.636009    Validation MSE: 23.718964
# Starting epoch 587 / 1500
# Loss: 16.633829    Validation MSE: 23.691880
# Starting epoch 588 / 1500
# Loss: 16.670187    Validation MSE: 23.677228
# Starting epoch 589 / 1500
# Loss: 16.313913    Validation MSE: 23.668565
# Starting epoch 590 / 1500
# Loss: 16.527305    Validation MSE: 23.644861
# Starting epoch 591 / 1500
# Loss: 16.703748    Validation MSE: 23.616783
# Starting epoch 592 / 1500
# Loss: 16.211017    Validation MSE: 23.617780
# Starting epoch 593 / 1500
# Loss: 16.940110    Validation MSE: 23.618082
# Starting epoch 594 / 1500
# Loss: 17.105040    Validation MSE: 23.588066
# Starting epoch 595 / 1500
# Loss: 16.531679    Validation MSE: 23.558095
# Starting epoch 596 / 1500
# Loss: 16.921479    Validation MSE: 23.531291
# Starting epoch 597 / 1500
# Loss: 16.702251    Validation MSE: 23.504523
# Starting epoch 598 / 1500
# Loss: 16.916850    Validation MSE: 23.490248
# Starting epoch 599 / 1500
# Loss: 15.799998    Validation MSE: 23.478844
# Starting epoch 600 / 1500
# Loss: 16.929351    Validation MSE: 23.451586
# Starting epoch 601 / 1500
# Loss: 16.555979    Validation MSE: 23.422484
# Starting epoch 602 / 1500
# Loss: 15.766305    Validation MSE: 23.393726
# Starting epoch 603 / 1500
# Loss: 16.504594    Validation MSE: 23.364762
# Starting epoch 604 / 1500
# Loss: 16.515545    Validation MSE: 23.336235
# Starting epoch 605 / 1500
# Loss: 16.212881    Validation MSE: 23.307884
# Starting epoch 606 / 1500
# Loss: 16.679416    Validation MSE: 23.278971
# Starting epoch 607 / 1500
# Loss: 16.549000    Validation MSE: 23.250276
# Starting epoch 608 / 1500
# Loss: 16.675094    Validation MSE: 23.224052
# Starting epoch 609 / 1500
# Loss: 16.657630    Validation MSE: 23.198281
# Starting epoch 610 / 1500
# Loss: 16.789431    Validation MSE: 23.170965
# Starting epoch 611 / 1500
# Loss: 16.218815    Validation MSE: 23.147815
# Starting epoch 612 / 1500
# Loss: 16.498421    Validation MSE: 23.126487
# Starting epoch 613 / 1500
# Loss: 16.756428    Validation MSE: 23.101122
# Starting epoch 614 / 1500
# Loss: 16.323559    Validation MSE: 23.074292
# Starting epoch 615 / 1500
# Loss: 16.698106    Validation MSE: 23.053041
# Starting epoch 616 / 1500
# Loss: 16.476994    Validation MSE: 23.030969
# Starting epoch 617 / 1500
# Loss: 16.200716    Validation MSE: 23.006982
# Starting epoch 618 / 1500
# Loss: 17.305069    Validation MSE: 22.983863
# Starting epoch 619 / 1500
# Loss: 16.094504    Validation MSE: 22.963395
# Starting epoch 620 / 1500
# Loss: 16.405083    Validation MSE: 22.942511
# Starting epoch 621 / 1500
# Loss: 16.151089    Validation MSE: 22.916012
# Starting epoch 622 / 1500
# Loss: 16.689932    Validation MSE: 22.900312
# Starting epoch 623 / 1500
# Loss: 17.559442    Validation MSE: 22.885110
# Starting epoch 624 / 1500
# Loss: 15.950284    Validation MSE: 22.860605
# Starting epoch 625 / 1500
# Loss: 17.339204    Validation MSE: 22.838041
# Starting epoch 626 / 1500
# Loss: 16.289116    Validation MSE: 22.816377
# Starting epoch 627 / 1500
# Loss: 15.856759    Validation MSE: 22.793004
# Starting epoch 628 / 1500
# Loss: 16.054148    Validation MSE: 22.766167
# Starting epoch 629 / 1500
# Loss: 15.467109    Validation MSE: 22.739296
# Starting epoch 630 / 1500
# Loss: 15.675385    Validation MSE: 22.712513
# Starting epoch 631 / 1500
# Loss: 16.985575    Validation MSE: 22.688651
# Starting epoch 632 / 1500
# Loss: 16.304527    Validation MSE: 22.666970
# Starting epoch 633 / 1500
# Loss: 15.684517    Validation MSE: 22.643353
# Starting epoch 634 / 1500
# Loss: 16.089047    Validation MSE: 22.623905
# Starting epoch 635 / 1500
# Loss: 16.663833    Validation MSE: 22.604587
# Starting epoch 636 / 1500
# Loss: 16.795349    Validation MSE: 22.579006
# Starting epoch 637 / 1500
# Loss: 16.360873    Validation MSE: 22.555251
# Starting epoch 638 / 1500
# Loss: 15.439943    Validation MSE: 22.531878
# Starting epoch 639 / 1500
# Loss: 16.496234    Validation MSE: 22.506693
# Starting epoch 640 / 1500
# Loss: 16.006618    Validation MSE: 22.482596
# Starting epoch 641 / 1500
# Loss: 16.685733    Validation MSE: 22.458842
# Starting epoch 642 / 1500
# Loss: 15.805301    Validation MSE: 22.434953
# Starting epoch 643 / 1500
# Loss: 16.078323    Validation MSE: 22.410955
# Starting epoch 644 / 1500
# Loss: 16.094961    Validation MSE: 22.385597
# Starting epoch 645 / 1500
# Loss: 16.417759    Validation MSE: 22.359669
# Starting epoch 646 / 1500
# Loss: 16.357570    Validation MSE: 22.336295
# Starting epoch 647 / 1500
# Loss: 15.982536    Validation MSE: 22.313237
# Starting epoch 648 / 1500
# Loss: 16.885795    Validation MSE: 22.288749
# Starting epoch 649 / 1500
# Loss: 16.172751    Validation MSE: 22.264643
# Starting epoch 650 / 1500
# Loss: 16.114263    Validation MSE: 22.241612
# Starting epoch 651 / 1500
# Loss: 15.837076    Validation MSE: 22.223805
# Starting epoch 652 / 1500
# Loss: 17.354977    Validation MSE: 22.204499
# Starting epoch 653 / 1500
# Loss: 16.592321    Validation MSE: 22.181215
# Starting epoch 654 / 1500
# Loss: 16.205735    Validation MSE: 22.158001
# Starting epoch 655 / 1500
# Loss: 16.399606    Validation MSE: 22.133073
# Starting epoch 656 / 1500
# Loss: 15.935736    Validation MSE: 22.108395
# Starting epoch 657 / 1500
# Loss: 15.642483    Validation MSE: 22.086485
# Starting epoch 658 / 1500
# Loss: 15.939389    Validation MSE: 22.066346
# Starting epoch 659 / 1500
# Loss: 16.246334    Validation MSE: 22.044293
# Starting epoch 660 / 1500
# Loss: 16.738086    Validation MSE: 22.022461
# Starting epoch 661 / 1500
# Loss: 16.510431    Validation MSE: 22.000038
# Starting epoch 662 / 1500
# Loss: 16.199517    Validation MSE: 21.982176
# Starting epoch 663 / 1500
# Loss: 16.294395    Validation MSE: 21.973663
# Starting epoch 664 / 1500
# Loss: 16.380151    Validation MSE: 21.962339
# Starting epoch 665 / 1500
# Loss: 15.548540    Validation MSE: 21.941284
# Starting epoch 666 / 1500
# Loss: 17.016349    Validation MSE: 21.918668
# Starting epoch 667 / 1500
# Loss: 16.754754    Validation MSE: 21.896353
# Starting epoch 668 / 1500
# Loss: 16.085489    Validation MSE: 21.873055
# Starting epoch 669 / 1500
# Loss: 16.012990    Validation MSE: 21.849474
# Starting epoch 670 / 1500
# Loss: 15.621130    Validation MSE: 21.831019
# Starting epoch 671 / 1500
# Loss: 15.387717    Validation MSE: 21.813745
# Starting epoch 672 / 1500
# Loss: 15.796695    Validation MSE: 21.790734
# Starting epoch 673 / 1500
# Loss: 15.729309    Validation MSE: 21.767603
# Starting epoch 674 / 1500
# Loss: 15.010810    Validation MSE: 21.745682
# Starting epoch 675 / 1500
# Loss: 16.058823    Validation MSE: 21.723929
# Starting epoch 676 / 1500
# Loss: 15.739085    Validation MSE: 21.705163
# Starting epoch 677 / 1500
# Loss: 16.843864    Validation MSE: 21.688117
# Starting epoch 678 / 1500
# Loss: 16.615733    Validation MSE: 21.679993
# Starting epoch 679 / 1500
# Loss: 15.870625    Validation MSE: 21.670079
# Starting epoch 680 / 1500
# Loss: 15.727760    Validation MSE: 21.649070
# Starting epoch 681 / 1500
# Loss: 16.467580    Validation MSE: 21.632553
# Starting epoch 682 / 1500
# Loss: 15.715431    Validation MSE: 21.614838
# Starting epoch 683 / 1500
# Loss: 16.364642    Validation MSE: 21.595432
# Starting epoch 684 / 1500
# Loss: 16.080138    Validation MSE: 21.575681
# Starting epoch 685 / 1500
# Loss: 15.668466    Validation MSE: 21.552800
# Starting epoch 686 / 1500
# Loss: 15.733352    Validation MSE: 21.529757
# Starting epoch 687 / 1500
# Loss: 16.546255    Validation MSE: 21.507101
# Starting epoch 688 / 1500
# Loss: 16.204382    Validation MSE: 21.484722
# Starting epoch 689 / 1500
# Loss: 16.693741    Validation MSE: 21.462291
# Starting epoch 690 / 1500
# Loss: 15.797784    Validation MSE: 21.441483
# Starting epoch 691 / 1500
# Loss: 15.846866    Validation MSE: 21.420185
# Starting epoch 692 / 1500
# Loss: 15.396517    Validation MSE: 21.398586
# Starting epoch 693 / 1500
# Loss: 16.006640    Validation MSE: 21.377201
# Starting epoch 694 / 1500
# Loss: 16.187415    Validation MSE: 21.354956
# Starting epoch 695 / 1500
# Loss: 15.101215    Validation MSE: 21.333390
# Starting epoch 696 / 1500
# Loss: 15.943578    Validation MSE: 21.312041
# Starting epoch 697 / 1500
# Loss: 15.591318    Validation MSE: 21.291979
# Starting epoch 698 / 1500
# Loss: 16.415834    Validation MSE: 21.271504
# Starting epoch 699 / 1500
# Loss: 16.346472    Validation MSE: 21.252398
# Starting epoch 700 / 1500
# Loss: 16.110049    Validation MSE: 21.242097
# Starting epoch 701 / 1500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-c7bc734e5e35> in <module>()
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# <ipython-input-6-0797740394fe> in main()
#     179                 try:
#     180                     _, summary = sess.run([train_op, summary_op],
# --> 181                                  {is_training: True})
#     182                     loss_history.append(sess.run(loss,
#     183                                                  {is_training: True}))
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
